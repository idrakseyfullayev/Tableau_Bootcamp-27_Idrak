# %% [markdown]
# ## Ders 4_3

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders4_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(31, 47):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):       
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Time Series - Date(Continuous) - Line Chart""", fontsize=18, fontweight='bold')        
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Özü Avtomatik Continuous olur""", fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result - (Sonra Plus-a basmaq kifayətdir Hierarchic-a üçün)""", 
                                                       fontsize=15, fontweight='bold')        
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hər ilin özünün Quarter-lərinin Sales-i""", fontsize=18, fontweight='bold')        
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hər ilin özünün Month-larının Sales-i """, fontsize=18, fontweight='bold')        
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hierarchy""", fontsize=18, fontweight='bold')
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hierarchy yaratmaq (1-ci üsul)""", fontsize=18, fontweight='bold')        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hierarchy yaratmaq (2-ci üsul)""", fontsize=18, fontweight='bold')        
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result""", fontsize=18, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hierarchy in Map""", fontsize=18, fontweight='bold')        
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Profit-i Size atmaq""", fontsize=18, fontweight='bold')
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Dairələrin Rəngi, Opacity və Border-i""", fontsize=18, fontweight='bold')        
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Calculated + Map (IF + SUM)""", fontsize=18, fontweight='bold')         
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Calculated-i Color-ə və Profit-i  Size-a atmaq""", 
                                                     fontsize=18, fontweight='bold')        
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Marks-dan Shape seçmək -  Shape-dən də növünü """, 
                                                     fontsize=15, fontweight='bold')
        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolları
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders4_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_4_3_.pdf'

# Başlıqlar
titles = [
    "Time Series - Date (Continuous) - Line Chart",
    "Özü Avtomatik Continuous olur",
    "Result - (Sonra Plus-a basmaq kifayətdir Hierarchic-a üçün)",
    "Hər ilin özünün Quarter-lərinin Sales-i",
    "Hər ilin özünün Month-larının Sales-i",
    "Hierarchy",
    "Hierarchy yaratmaq (1-ci üsul)",
    "Hierarchy yaratmaq (2-ci üsul)",
    "",
    "Result",
    "Hierarchy in Map",
    "Profit-i Size atmaq",
    "Dairələrin Rəngi, Opacity və Border-i",
    "Calculated + Map (IF + SUM)",
    "Calculated-i Color-ə və Profit-i Size-a atmaq",
    "Marks-dan Shape seçmək - Shape-dən də növünü"
]

# Arial fontunu qeyd edirik
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

# 31–46 şəkilləri PDF-ə əlavə edirik
for i in range(31, 47):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini hesablayırıq
    aspect = img.width / img.height
    available_height = height - 90
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlıq
    title_index = i - 31
    title = titles[title_index] if title_index < len(titles) else ""

    if title:
        c.setFont("Arial", 13)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatları
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli yerləşdir
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    # Yeni səhifəyə keçirik
    c.showPage()

# PDF-i yadda saxlayırıq
c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_4_3_.pdf
