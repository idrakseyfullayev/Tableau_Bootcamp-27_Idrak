# %% [markdown]
# ## Dərs 2_2

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders2_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(19, 35):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field- FIXED """, fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field- FIXED + SUM""", 
                                                         fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Calculated-i Dimension bölməsinə göndərmək""", 
                                                         fontsize=18, fontweight='bold')                   
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field- Fixed_Customer_ID_Sum > 60000 Customer_ID-lər """, 
                                                                 fontsize=13, fontweight='bold')        
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Calculated-i Dimension bölməsinə göndərmək (60000 > olanların ID-ləri)""", 
                                                                 fontsize=13, fontweight='bold')        
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field- COUNTD + IF (60000 > olanların ID-lərin sayı)""", 
                                                                 fontsize=13, fontweight='bold')       
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Area Chart""", fontsize=18, fontweight='bold')        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')     
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')  
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Area Chart - Hər il üçün Percentage fo Total""", fontsize=18, fontweight='bold')
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Compute Using - Customer Segment seçmək""", fontsize=18, fontweight='bold')        
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result 1""", fontsize=18, fontweight='bold')
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result 2""", fontsize=18, fontweight='bold') 
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result 3 (Customer Segment-i Label-dən çıxartmaq lazımdır)""", 
                                                                 fontsize=14, fontweight='bold')
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result 3 (Bar-da Customer Segment-i Label-a qaytarmaq lazımdır)""", 
                                                                 fontsize=14, fontweight='bold')        
        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolu və çıxış faylı
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders2_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders2_2.pdf'

# Başlıqlar (plt.title hissəsindən çıxarılıb)
titles = [
    "Create Calculated Field - FIXED",
    "Create Calculated Field - FIXED + SUM",
    "Calculated-i Dimension bölməsinə göndərmək",
    "Create Calculated Field - Fixed_Customer_ID_Sum > 60000 Customer_ID-lər",
    "Calculated-i Dimension bölməsinə göndərmək (60000 > olanların ID-ləri)",
    "Create Calculated Field - COUNTD + IF (60000 > olanların ID-lərin sayı)",
    "Area Chart",
    "",
    "",
    "",
    "Area Chart - Hər il üçün Percentage fo Total",
    "Compute Using - Customer Segment seçmək",
    "Result 1",
    "Result 2",
    "Result 3 (Customer Segment-i Label-dən çıxartmaq lazımdır)",
    "Result 3 (Bar-da Customer Segment-i Label-a qaytarmaq lazımdır)"
]

# Arial fontunu qeyd edirik
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

# 19–34 şəkilləri PDF-ə əlavə edirik
for i in range(19, 35):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini hesablayırıq
    aspect = img.width / img.height
    available_height = height - 90
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlığı əlavə et
    title_index = i - 19
    if title_index < len(titles):
        title = titles[title_index]
    else:
        title = ""

    if title:
        c.setFont("Arial", 14)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatlarını təyin et
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli yerləşdir
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    c.showPage()

# PDF faylı tamamla
c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders2_2.pdf
