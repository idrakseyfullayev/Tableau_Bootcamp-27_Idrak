# %% [markdown]
# ## Dərs 2_1

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders2_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 19):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Measure Funksiyasını Dəyişmək""", fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field""", fontsize=18, fontweight='bold')        
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')               
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field""", fontsize=18, fontweight='bold')         
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field""", fontsize=18, fontweight='bold')
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field Edit""", fontsize=18, fontweight='bold')        
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - IF""", fontsize=18, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Alternative Way""", fontsize=18, fontweight='bold')        
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - SUM + IF""", fontsize=18, fontweight='bold')        
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - IF + OR""", fontsize=18, fontweight='bold')         
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - COUNT (NULL olmayan sətirlərin sayı)""", 
                                                           fontsize=15, fontweight='bold')         
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - COUNTD (Unikal və NULL olmayan sətirlərin sayı)""", 
                                                           fontsize=13, fontweight='bold')       
    if i == 16:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - COUNTD + IF +AND """, fontsize=18, fontweight='bold')       
    if i == 17:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Create Calculated Field - IF +AND""", fontsize=18, fontweight='bold') 
        
        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolu və çıxış faylı
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders2_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_2_1.pdf'

# Başlıqlar
titles = [
    "Measure Funksiyasını Dəyişmək", "", "Create Calculated Field", "", 
    "Create Calculated Field", "", "Create Calculated Field", "", 
    "Create Calculated Field Edit", "Create Calculated Field - IF", 
    "Alternative Way", "Create Calculated Field - SUM + IF", "", 
    "Create Calculated Field - IF + OR", 
    "Create Calculated Field - COUNT (NULL olmayan sətirlərin sayı)", 
    "Create Calculated Field - COUNTD (Unikal və NULL olmayan sətirlərin sayı)", 
    "Create Calculated Field - COUNTD + IF + AND", 
    "Create Calculated Field - IF + AND"
]

# Arial fontunu qeyd edirik
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

for i in range(1, 19):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini tapırıq
    aspect = img.width / img.height

    available_height = height - 90
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlıq əlavə et
    title = titles[i - 1]
    if title:
        c.setFont("Arial", 14)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatları
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli yerləşdir
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    c.showPage()

c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_2_1.pdf
