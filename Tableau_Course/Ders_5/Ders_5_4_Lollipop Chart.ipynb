# %% [markdown]
# ## Ders 5_4

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders5_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(55, 66):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):       
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Lollipop Chart - eyni Measure-ı Row-a 2 dəfə atırıq""", 
                                             fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""2-ci Vizualı Circle etmək""", 
                                             fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""1-ci Vizualı Bar etmək""", 
                                             fontsize=18, fontweight='bold')        
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Dual Axis etmək""", 
                                             fontsize=18, fontweight='bold')        
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Size-ı dəyişmək (Hər iki Axis-də)""", 
                                             fontsize=18, fontweight='bold')        
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Circle-ı Shape ilə əvəz etmək""", 
                                             fontsize=18, fontweight='bold')        
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Row-da Measure-lərin yerini dəyişmək""", 
                                             fontsize=18, fontweight='bold')          
        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""State-i Shape-ə atmaq""", 
                                             fontsize=18, fontweight='bold')        
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Reslt - Hər Lollipop başlığı fərqli olur """, 
                                             fontsize=18, fontweight='bold')        
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Lollipop-da Shape-i dəyişmək""", 
                                             fontsize=18, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""State-i Color-ə atmaq""", 
                                             fontsize=18, fontweight='bold')               
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolları
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders5_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_5_4.pdf'

# Başlıqlar (plt.title-lardan)
titles = [
    "Lollipop Chart - eyni Measure-ı Row-a 2 dəfə atırıq",
    "2-ci Vizualı Circle etmək",
    "1-ci Vizualı Bar etmək",
    "Dual Axis etmək",
    "Size-ı dəyişmək (Hər iki Axis-də)",
    "Circle-ı Shape ilə əvəz etmək",
    "Row-da Measure-lərin yerini dəyişmək",
    "State-i Shape-ə atmaq",
    "Result - Hər Lollipop başlığı fərqli olur",
    "Lollipop-da Shape-i dəyişmək",
    "State-i Color-ə atmaq"
]

# Arial fontu qeyd olunur
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

# 55–65 şəkilləri PDF-ə əlavə edirik
for i in range(55, 66):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini saxla
    aspect = img.width / img.height
    available_height = height - 100
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlıq seçimi
    title_index = i - 55
    title = titles[title_index] if title_index < len(titles) else ""

    if title:
        c.setFont("Arial", 13)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatları
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli PDF-ə əlavə et
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    # Yeni səhifə
    c.showPage()

# PDF-i yadda saxla
c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_5_4.pdf
