# %% [markdown]
# ## Ders 5_5

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders5_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(66, 78):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):              
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Total Participation - Create Calculated Field""", 
                                             fontsize=18, fontweight='bold')        
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Year-i 'Date' tipinə çevirmək""", 
                                             fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Year-i 'Convert to Continuous' etmək""", 
                                             fontsize=18, fontweight='bold')        
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart""", 
                                             fontsize=18, fontweight='bold')        
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Sum(Total Participation) - Quick Table Calculation - Rank""", 
                                             fontsize=13.5, fontweight='bold')        
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Sum(Total Participation) - Compute Using - Sport""", 
                                             fontsize=13.5, fontweight='bold')               
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Edit Axis (Rank çoxdan aza oldugu üçün)""", 
                                             fontsize=16, fontweight='bold')        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Edit Axis(Rank of Total participation) - Scale - Reversed)""", 
                                             fontsize=13.5, fontweight='bold')        
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Dual Axis etmək (Row-dakı Measure-ı CTR sıxıb yanına atmaq)""", 
                                             fontsize=12, fontweight='bold')        
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Axis-dəki Vizuallardan birini Circle etmək""", 
                                             fontsize=14, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Axis üzərində Sağ Click  - Synchronise Axis etmək""", 
                                             fontsize=15, fontweight='bold')        
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bump Chart - Sport-u Label-a atmaq""", 
                                             fontsize=16, fontweight='bold')         
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolları
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders5_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_5_5.pdf'

# Başlıqlar (plt.title-lardan)
titles = [
    "Total Participation - Create Calculated Field",
    "Year-i 'Date' tipinə çevirmək",
    "Year-i 'Convert to Continuous' etmək",
    "Bump Chart",
    "Bump Chart - Sum(Total Participation) - Quick Table Calculation - Rank",
    "Bump Chart - Sum(Total Participation) - Compute Using - Sport",
    "Bump Chart - Edit Axis (Rank çoxdan aza oldugu üçün)",
    "Bump Chart - Edit Axis (Rank of Total participation) - Scale - Reversed)",
    "Bump Chart - Dual Axis etmək (Row-dakı Measure-ı CTR sıxıb yanına atmaq)",
    "Bump Chart - Axis-dəki Vizuallardan birini Circle etmək",
    "Bump Chart - Axis üzərində Sağ Click  - Synchronise Axis etmək",
    "Bump Chart - Sport-u Label-a atmaq"
]

# Arial fontunu qeyd et
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

# 66–77 şəkilləri PDF-ə əlavə edirik
for i in range(66, 78):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini saxla
    aspect = img.width / img.height
    available_height = height - 100
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlıq
    title_index = i - 66
    title = titles[title_index] if title_index < len(titles) else ""

    if title:
        c.setFont("Arial", 13)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatları
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli PDF-ə əlavə et
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    # Yeni səhifə
    c.showPage()

# PDF-i yadda saxla
c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders_5_5.pdf
