# %% [markdown]
# ## Ders 3_5

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders3_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(60, 78):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Parameter + Calculated (Parameter-i Calculated-ə bağlamaq)""", 
                                                  fontsize=14, fontweight='bold')        
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Parameter-də List yaratmaq""", fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Show Parameter""", fontsize=18, fontweight='bold')
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Calculated yaratmaq (Parameter-ə bağlamaq üçün)""", fontsize=18, fontweight='bold')        
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Calculated-i Rows, Order Date Columns atmaq (Parameter-də Sales seçmək)""", 
                                                                fontsize=13, fontweight='bold')         
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Parameter-də Profit seçmək""", fontsize=18, fontweight='bold')        
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Datanı hazırlamaq - JOIN""", fontsize=18, fontweight='bold')        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Scatter Plot (Aggregate Measures - Active)""", fontsize=18, fontweight='bold')
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Scatter Plot - Product üzrə - (Aggregate Measures - Active)""", 
                                                      fontsize=16, fontweight='bold')        
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Trend Line""", fontsize=18, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result""", fontsize=18, fontweight='bold')
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Scatter Plot (Aggregate Measures - None Active)""", fontsize=18, fontweight='bold')        
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')         
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Product-ı Color-ə atmaq""", fontsize=18, fontweight='bold')        
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Bir Product üzrə Baxmaq""", fontsize=18, fontweight='bold')
    if i == 16:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Product-ı Color-ə və Filter-ə atmaq (Bir Product üzrə)""", 
                                                 fontsize=16, fontweight='bold')        
    if i == 17:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result""", fontsize=16, fontweight='bold')  
        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolları
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders3_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders3_5_.pdf'

# Başlıqlar (plt.title hissələrindən götürülüb)
titles = [
    "Parameter + Calculated (Parameter-i Calculated-ə bağlamaq)",
    "Parameter-də List yaratmaq",
    "Show Parameter",
    "Calculated yaratmaq (Parameter-ə bağlamaq üçün)",
    "Calculated-i Rows, Order Date Columns atmaq (Parameter-də Sales seçmək)",
    "Parameter-də Profit seçmək",
    "Datanı hazırlamaq - JOIN",
    "Scatter Plot (Aggregate Measures - Active)",
    "Scatter Plot - Product üzrə - (Aggregate Measures - Active)",
    "Trend Line",
    "Result",
    "Scatter Plot (Aggregate Measures - None Active)",
    "",
    "",
    "Product-ı Color-ə atmaq",
    "Bir Product üzrə Baxmaq",
    "Product-ı Color-ə və Filter-ə atmaq (Bir Product üzrə)",
    "Result"
]

# Arial fontunu qeyd edirik
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

# 60–77 şəkilləri PDF-ə əlavə edirik
for i in range(60, 78):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini hesablayırıq
    aspect = img.width / img.height
    available_height = height - 90
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlıq
    title_index = i - 60
    if title_index < len(titles):
        title = titles[title_index]
    else:
        title = ""

    if title:
        c.setFont("Arial", 13)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatları
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli yerləşdir
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    c.showPage()

# PDF-i tamamla
c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders3_5_.pdf
