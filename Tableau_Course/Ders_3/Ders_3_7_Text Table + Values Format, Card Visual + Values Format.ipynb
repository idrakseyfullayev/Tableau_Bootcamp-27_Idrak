# %% [markdown]
# ## Ders 3_7

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders3_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(85, 102):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):       
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table (1-ci üsul)""", fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Result""", fontsize=18, fontweight='bold')        
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table-ı Filter etmək""", fontsize=18, fontweight='bold')
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table (2-ci üsul)""", fontsize=18, fontweight='bold')       
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Font""", fontsize=18, fontweight='bold')        
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Alingment""", fontsize=18, fontweight='bold')        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Shading""", fontsize=18, fontweight='bold')        
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Shading - Row Banding - Band Size""", 
                                                             fontsize=14, fontweight='bold')
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Borders - Row Divider""", 
                                                             fontsize=14, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Lines (Amma bu Vizaul-da heç nə etmir)""", 
                                                             fontsize=14, fontweight='bold')        
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Text Table Values Format - Borders - Default - Cell - Pane - Header""", 
                                                             fontsize=12, fontweight='bold')
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Card Visual""", fontsize=18, fontweight='bold')
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Card Visual - Values Format""", fontsize=18, fontweight='bold')        
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Card Visual - Values Format - Borders - Row Divider""", 
                                                      fontsize=18, fontweight='bold')         
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Card Visual - Values Format - Aligment - Default - Pane - Header""", 
                                                          fontsize=14, fontweight='bold')        
    if i == 16:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Card Visual - Values Format - Font - Default - Pane - Header""", 
                                                          fontsize=14, fontweight='bold')         
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()

# %% [markdown]
# ## PDF yaratmaq

# %%
from PIL import Image
from reportlab.lib.pagesizes import A4
from reportlab.lib.utils import ImageReader
from reportlab.pdfgen import canvas
from reportlab.pdfbase.ttfonts import TTFont
from reportlab.pdfbase import pdfmetrics

# Fayl yolları
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders3_'
output_pdf = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders3_7_.pdf'

# Başlıqlar (plt.title hissələrindən götürülüb)
titles = [
    "Text Table (1-ci üsul)",
    "",
    "Result",
    "Text Table-ı Filter etmək",
    "Text Table (2-ci üsul)",
    "Text Table Values Format - Font",
    "Text Table Values Format - Alignment",
    "Text Table Values Format - Shading",
    "Text Table Values Format - Shading - Row Banding - Band Size",
    "Text Table Values Format - Borders - Row Divider",
    "Text Table Values Format - Lines (Amma bu Vizual-da heç nə etmir)",
    "Text Table Values Format - Borders - Default - Cell - Panel - Header",
    "Card Visual",
    "Card Visual - Values Format",
    "Card Visual - Values Format - Borders - Row Divider",
    "Card Visual - Values Format - Alignment - Default - Pane - Header",
    "Card Visual - Values Format - Font - Default - Pane - Header"
]

# Arial fontunu qeyd edirik
pdfmetrics.registerFont(TTFont('Arial', r'C:\Windows\Fonts\arial.ttf'))

# PDF yaradırıq
c = canvas.Canvas(output_pdf, pagesize=A4)
width, height = A4

# 85–101 şəkilləri PDF-ə əlavə edirik
for i in range(85, 102):
    full_path = f'{base_path}{i}.jpg'
    img = Image.open(full_path)

    # Şəkil nisbətini hesablayırıq
    aspect = img.width / img.height
    available_height = height - 90
    available_width = width - 40
    new_width = available_width
    new_height = new_width / aspect

    if new_height > available_height:
        new_height = available_height
        new_width = new_height * aspect

    # Başlıq
    title_index = i - 85
    if title_index < len(titles):
        title = titles[title_index]
    else:
        title = ""

    if title:
        c.setFont("Arial", 13)
        c.drawCentredString(width / 2, height - 40, title)
        top_y = height - 70
    else:
        top_y = height - 40

    # Şəkilin koordinatları
    x = (width - new_width) / 2
    y = top_y - new_height

    # Şəkli yerləşdir
    img_reader = ImageReader(img)
    c.drawImage(img_reader, x, y, width=new_width, height=new_height)

    c.showPage()

# PDF-i tamamla
c.save()
print("✅ PDF yaradıldı:", output_pdf)
# Out:
# ✅ PDF yaradıldı: C:\Users\dell\Desktop\Tableau\Tableau_Course\Ders3_7_.pdf
