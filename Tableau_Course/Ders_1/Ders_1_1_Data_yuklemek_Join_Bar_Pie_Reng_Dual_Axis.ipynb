# %% [markdown]
# ## Dərs 1_1

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders1_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(1, 18):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Tableau-ya Datanı növünə görə çəkmək""", fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Yüklədiyimiz Datanın Sheet-ləri""", fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Join etmək üçün növbəti Datanı yükləmək""", fontsize=18, fontweight='bold')
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Join etmək üçün List1-i açmaq lazımdır""", fontsize=18, fontweight='bold')
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Join etmək və növünü seçmək""", fontsize=18, fontweight='bold')
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Tamamilə Yeni Data gətirmək""", fontsize=18, fontweight='bold')
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sütunun tipini dəyişmək""", fontsize=18, fontweight='bold')
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Vizualı ekrana sıxışdırır""", fontsize=18, fontweight='bold')
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Chart-ın növünü dəyişmək""", fontsize=18, fontweight='bold')
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Pie Chart-da dəyəri Faizlə göstərmək""", fontsize=18, fontweight='bold')
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Dəyərin üstünə Click edib sonra sürüşdürüb lazım olan yerə qoymaq""", 
                                                                      fontsize=14, fontweight='bold')
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Chart-ın Rənglərini dəyişmək""", fontsize=18, fontweight='bold')
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Daha Geniş Rəng Seçimi üçün Double Click False(True) üzərində""", 
                                                      fontsize=14, fontweight='bold')        
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Seçilmiş Rəngi yaddaşda saxlamaq""", fontsize=18, fontweight='bold')
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Dual Axis etmək yolları(Üzərində sağ Click və ya..)""", fontsize=18, fontweight='bold')        
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 16:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hər Axis-də olan Chart-ın növünü dəyişmək""", fontsize=18, fontweight='bold')
        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
