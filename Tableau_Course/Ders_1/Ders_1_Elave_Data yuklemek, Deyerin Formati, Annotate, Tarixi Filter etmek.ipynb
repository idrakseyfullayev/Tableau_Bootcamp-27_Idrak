# %% [markdown]
# ## Dərs 1 Əlavə

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders1_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(48, 65):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Data yükləmək üçün Sürüşdürmək kifayətdir""", fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sheet-in Başlıq adını Dəyişmək""", fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Pie-da dəyərin Formatını Dəyişmək""", fontsize=18, fontweight='bold')
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')        
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Annotate vermək (Sağ Click etməklə)""", fontsize=18, fontweight='bold')        
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Annotate-in Formatını Dəyişmək (Üzərində sağ Click)""", fontsize=18, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Category-ni Vizualdan çixardır (Sanki Filter verib Exclude edirsən)""", 
                                                              fontsize=14, fontweight='bold')
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Ən çox satılanlar hər Product Type-dan (1-ci Nested Sort etmək)""", 
                                                          fontsize=14, fontweight='bold') 
    if i == 13:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')         
    if i == 14:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Aylar üzrə Filter""", fontsize=18, fontweight='bold')
    if i == 15:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""""", fontsize=18, fontweight='bold')
    if i == 16:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""County üzrə və Product üzrə ən çox satılan""", fontsize=18, fontweight='bold')        
        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
