# %% [markdown]
# ## Dərs 1_3

# %%
from PIL import Image

# Fayl yolunun əsas hissəsi
base_path = r'C:\Users\dell\Desktop\Tableau\Tableau_Course\Pictures\Ders1_'

# Şəkilləri saxlayacağımız siyahı
image_list = []

# 1-dən 5-ə qədər olan şəkilləri dövr ilə açırıq
for i in range(35, 48):  # 1-dən 5-ə qədər   
    full_path = f'{base_path}{i}.jpg'  # Fayl yolunu dinamik olaraq yaradırıq
    img = Image.open(full_path)
    image_list.append(img)  # Şəkili siyahıya əlavə edirik

# Nəticə: images siyahısında bütün yüklənmiş şəkillər olacaq

import matplotlib.pyplot as plt

# Şəkilləri göstərin
for i, image in enumerate(image_list):
    if i == 0:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Show Filter (İstifadəçi də Filter verə bilsin)""", fontsize=18, fontweight='bold')
    if i == 1:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Show Filter-də Axtarış Box-ı açmaq """, fontsize=18, fontweight='bold')
    if i == 2:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Show Filter-də Axtarış Box-sının görünüşü""", fontsize=18, fontweight='bold')       
    if i == 3:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Data yükləyəndə bir neçə Sheet varsa özün atmalısan Sheet-i Drag sahəsinə""", 
                                                                   fontsize=13, fontweight='bold')
    if i == 4:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension""", fontsize=18, fontweight='bold')
    if i == 5:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-nın Növləri""", fontsize=18, fontweight='bold')        
    if i == 6:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-da Sort By - Field""", fontsize=18, fontweight='bold')       
    if i == 7:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-da Sort By - Manual""", fontsize=18, fontweight='bold')
    if i == 8:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-da Sort By - Field (Product Sub-Category üzrə Sort)""", 
                                                                  fontsize=13, fontweight='bold')
    if i == 9:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-da Sort By - Field (Anlamaq üçün Color-dan istifadə)""", 
                                                                  fontsize=13, fontweight='bold')        
    if i == 10:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-da Sort By - Nested (Hər Region içində Product Sub-Category üzrə Sort)""", 
                                                                  fontsize=11, fontweight='bold')       
    if i == 11:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Sorting a Dimension-da Sort By - Nested (Anlamaq üçün Color-dan istifadə)""", 
                                                                  fontsize=11, fontweight='bold')        
    if i == 12:
        plt.figure(figsize=(10, 8))  # Şəkilin ölçüsü
        plt.title("""Hər hansı Category-ni Highlight edib izləmək""", 
                                                                  fontsize=14, fontweight='bold')        
    plt.imshow(image)        
    plt.imshow(image)
    plt.axis('off')  # Oxları gizlətmək üçün
    plt.show()
